# %%
from Fluxion import *

# %%
# %%Fluxion -v WARNING --disable_caching -ql -s Example1
#
# class Example1(Scene):
#     def construct(self):
#         self.add(Circle())

# %%
# %%Fluxion -v WARNING --disable_caching -qm HelloFluxion
#
# # set the maximum width for video outputs to a predefined value
# config.media_width = "20vw"
# # embed video
# config.media_embed = True
#
# class HelloFluxion(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         banner_large = FluxionBanner(dark_theme=False).scale(0.7)
#         self.play(banner_large.create())
#         self.play(banner_large.expand())
